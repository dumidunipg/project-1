# %%
# Dependencies
import hvplot.pandas
import pandas as pd
import numpy as np
import requests
import json
import random

# Import API key
from geoapify_key import api_key

# %%
# Read states.csv and create it as a Dataframe
states_loc = pd.read_csv('states.csv')
states_loc_df = pd.DataFrame(states_loc)
states_loc_df.head()
# Out:
#   state   latitude   longitude        name
# 0    AK  63.588753 -154.493062      Alaska
# 1    AL  32.318231  -86.902298     Alabama
# 2    AR  35.201050  -91.831833    Arkansas
# 3    AZ  34.048928 -111.093731     Arizona
# 4    CA  36.778261 -119.417932  California

# %%
# Read states_area.csv and merge with states.csv
states_area = pd.read_csv('states_area.csv')
states_area_df = pd.DataFrame(states_area)

# Format Dataframe for same column name and area values to int
states_area_df.rename(columns={"state": "name", 
                               "Total Area (sq km)": "area (sq km)"}, 
                               inplace=True)
states_area_df['area (sq km)'] = [int(area.replace(",", "")) for area in states_area_df['area (sq km)']]
states_df = pd.merge(states_loc_df,states_area_df, on='name')
states_df.head()
# Out:
#   state   latitude   longitude        name  area (sq km)        lon1  \
# 0    AK  63.588753 -154.493062      Alaska       1723337 -130.000000
# 1    AL  32.318231  -86.902298     Alabama        135767  -84.883333
# 2    AR  35.201050  -91.831833    Arkansas        137732  -89.650000
# 3    AZ  34.048928 -111.093731     Arizona        295234 -109.050000
# 4    CA  36.778261 -119.417932  California        423967 -114.133333
#
#         lat1        lon2       lat2
# 0  51.333333  172.000000  71.833333
# 1  30.183333  -88.466667  35.000000
# 2  33.000000  -94.616667  36.500000
# 3  31.333333 -114.816667  37.000000
# 4  32.533333 -124.433333  42.000000

# %%
# Set base URLs for Places API and Geocode API
places_url = 'https://api.geoapify.com/v2/places?'
geocode_url = 'https://api.geoapify.com/v1/geocode/search?'

# Select the categories to search and set columns for them
categories_interested = ["commercial", "service", "tourism", "religion", "beach", "production", "leisure"]
for category in categories_interested:
    states_df[category] = None

# Counter for number of states with no data in a given category
states_missing = 0

# Initialize API search
print("Starting Services Search")
print('-'*80)

for index, row in states_df.iterrows():
    
    print(f"Searching {states_df.loc[index, 'name'].upper()}")
    # Get coordinate values for filter and bias parameters
    longitude = row['longitude']
    latitude = row['latitude']
    lon1 = row['lon1']
    lat1 = row['lat1']
    lon2 = row['lon2']
    lat2 = row['lat2']
    for category in categories_interested:
        
        # Set parameters for Places API response
        params = {
            "categories": category,
            "apiKey": api_key,
            "limit": 10,
            "filter": f"rect:{lon1},{lat1},{lon2},{lat2}",
            "bias": f"proximity:{longitude},{latitude}"
        }
        places_json = requests.get(places_url, params=params).json()

        # Check the returned list and break if the length is 0
        if int(len(places_json["features"])) == 0:
            print(f"No results found for {states_df.loc[index, 'name']} in {category}")
            print('-'*80)
            states_missing += 1
            break
        else:
        
            # Counter for number of results with mismatch in state
            result_wrong = 0

            # Check that the place is in the respective state
            for result in places_json['features']:
                try:
                    if result['properties']['state'] != states_df.loc[index, 'name']:
                        print(f"{result['properties']['state']} is not in the state of {states_df.loc[index, 'name']}!")
                        result_wrong += 1
                        break
                
                except:
                    result_wrong += 1
                    break
                else:
                    
                    # Use the Geocode API with place_id to obtain popularity index
                    for geo_result in places_json['features']:
                        place_id = geo_result['properties']['place_id']
                        try:
                            geo_params = {
                                    "apiKey": api_key,
                                    "text": geo_result['properties']['formatted'],
                                    "limit": 2,
                                    "filter": f"place:{place_id}",
                                }
                        
                        except KeyError:
                            geo_params = {
                                    "apiKey": api_key,
                                    "state": result['properties']['state_code'],
                                    "limit": 2,
                                    "filter": f"place:{place_id}",
                                }
                        geocode_json = requests.get(geocode_url, params=geo_params).json()
                        
                        # Setup average popularity list
                        geo_popularity = [0]
                        for geo_feature in geocode_json['features']:
                            if ((geo_feature['properties']['rank']['confidence'] == 1) | (geo_feature['properties']['rank']['match_type'] == "full_match") | (geo_feature['properties']['rank']['match_type'] == "inner_part")):
                                try:
                                    geo_popularity.append(float(geo_feature['properties']['rank']['popularity']))
                                    
                                    if float(geo_feature['properties']['rank']['popularity']) > max(geo_popularity):
                                        max_popularity = float(geo_feature['properties']['rank']['popularity'])
                                    min_popularity = float(geo_feature['properties']['rank']['popularity'])
                                
                                except KeyError:
                                    geo_popularity.append(0)

                        try:
                            states_df.loc[index, f'{category}_popularity'] = sum(geo_popularity) / len(geo_popularity)
                        
                        except ZeroDivisionError:
                            continue
                    
            try:
                states_df.loc[index, category] = places_json['features'][0]['properties']['name']
            except KeyError:
                try:
                    states_df.loc[index, category] = places_json['features'][0]['properties']['formatted']
                except KeyError:    
                    states_df.loc[index, category] = None
            if result_wrong != 0:
                print(f'Number of wrong results in {category}: {result_wrong}')
            
    else:
        print('-'*80)
        continue
    # break
print("Ending Services Search")
print(f"Number of Places API response with no data: {states_missing}")

empty_cols = [col for col in states_df.columns if ((states_df[col].isnull().all()) | (states_df[col].all() == None) | (states_df[col].count() < 25))]
states_df.drop(empty_cols, axis= 1, inplace=True)
# Out:
# Starting Services Search
# --------------------------------------------------------------------------------
# Searching ALASKA
# No results found for Alaska in commercial
# --------------------------------------------------------------------------------
# Searching ALABAMA
# No date keyword found for Alabama in commercial
# No date keyword found for Alabama in service
# Number of wrong results in tourism: 1
# No date keyword found for Alabama in religion
# Number of wrong results in religion: 1
# No results found for Alabama in beach
# --------------------------------------------------------------------------------
# Searching ARKANSAS
# No date keyword found for Arkansas in commercial
# Number of wrong results in commercial: 1
# No date keyword found for Arkansas in service
# Number of wrong results in service: 1
# No date keyword found for Arkansas in tourism
# Number of wrong results in tourism: 1
# No date keyword found for Arkansas in religion
# Number of wrong results in religion: 1
# No date keyword found for Arkansas in beach
# Number of wrong results in beach: 1
# No date keyword found for Arkansas in production
# Number of wrong results in production: 1
# No date keyword found for Arkansas in leisure
# Number of wrong results in leisure: 1
# Arkansas TEST: Yancey Park
# --------------------------------------------------------------------------------
# Searching ARIZONA
# No date keyword found for Arizona in commercial
# Number of wrong results in commercial: 1
# No date keyword found for Arizona in service
# Number of wrong results in service: 1
# No date keyword found for Arizona in tourism
# Number of wrong results in tourism: 1
# No date keyword found for Arizona in religion
# Number of wrong results in religion: 1
# No results found for Arizona in beach
# --------------------------------------------------------------------------------
# Searching CALIFORNIA
# No date keyword found for California in commercial
# Number of wrong results in commercial: 1
# No date keyword found for California in service
# Number of wrong results in service: 1
# No date keyword found for California in tourism
# Number of wrong results in tourism: 1
# No date keyword found for California in religion
# Number of wrong results in religion: 1
# No date keyword found for California in beach
# Number of wrong results in beach: 1
# No date keyword found for California in production
# Number of wrong results in production: 1
# No date keyword found for California in leisure
# Number of wrong results in leisure: 1
# California TEST: Winton Park
# --------------------------------------------------------------------------------
# Searching COLORADO
# No date keyword found for Colorado in commercial
# Number of wrong results in commercial: 1
# No date keyword found for Colorado in service
# Number of wrong results in service: 1
# No date keyword found for Colorado in tourism
# Number of wrong results in tourism: 1
# No date keyword found for Colorado in religion
# Number of wrong results in religion: 1
# Number of wrong results in beach: 2
# No date keyword found for Colorado in production
# Number of wrong results in production: 2
# No date keyword found for Colorado in leisure
# Number of wrong results in leisure: 2
# Colorado TEST: White River National Forest
# --------------------------------------------------------------------------------
# Searching CONNECTICUT
# No date keyword found for Connecticut in commercial
# Number of wrong results in commercial: 2
# No date keyword found for Connecticut in service
# Number of wrong results in service: 2
# No date keyword found for Connecticut in tourism
# Number of wrong results in tourism: 2
# No date keyword found for Connecticut in religion
# Number of wrong results in religion: 2
# Number of wrong results in beach: 3
# No date keyword found for Connecticut in production
# Number of wrong results in production: 3
# No date keyword found for Connecticut in leisure
# Number of wrong results in leisure: 3
# Connecticut TEST: Echo Lake Park
# --------------------------------------------------------------------------------
# Searching DELAWARE
# No date keyword found for Delaware in commercial
# Number of wrong results in commercial: 3
# No date keyword found for Delaware in service
# Number of wrong results in service: 3
# No date keyword found for Delaware in tourism
# Number of wrong results in tourism: 3
# No date keyword found for Delaware in religion
# Number of wrong results in religion: 3
# No date keyword found for Delaware in beach
# Number of wrong results in beach: 3
# No date keyword found for Delaware in production
# Number of wrong results in production: 3
# No date keyword found for Delaware in leisure
# Number of wrong results in leisure: 3
# Delaware TEST: Browns Branch County Park
# --------------------------------------------------------------------------------
# Searching FLORIDA
# No date keyword found for Florida in commercial
# Number of wrong results in commercial: 3
# No date keyword found for Florida in service
# Number of wrong results in service: 3
# No date keyword found for Florida in tourism
# Number of wrong results in tourism: 3
# No date keyword found for Florida in religion
# Number of wrong results in religion: 3
# Number of wrong results in beach: 4
# No date keyword found for Florida in production
# Number of wrong results in production: 4
# No date keyword found for Florida in leisure
# Number of wrong results in leisure: 4
# Florida TEST: Arbuckle Wildlife Management Area
# --------------------------------------------------------------------------------
# Searching GEORGIA
# No date keyword found for Georgia in commercial
# Number of wrong results in commercial: 4
# No date keyword found for Georgia in service
# Number of wrong results in service: 4
# No date keyword found for Georgia in tourism
# Number of wrong results in tourism: 4
# No date keyword found for Georgia in religion
# Number of wrong results in religion: 4
# No results found for Georgia in beach
# --------------------------------------------------------------------------------
# Searching HAWAII
# No date keyword found for Hawaii in commercial
# Number of wrong results in commercial: 4
# No date keyword found for Hawaii in service
# Number of wrong results in service: 4
# No date keyword found for Hawaii in tourism
# Number of wrong results in tourism: 4
# No date keyword found for Hawaii in religion
# Number of wrong results in religion: 4
# No date keyword found for Hawaii in beach
# Number of wrong results in beach: 4
# No date keyword found for Hawaii in production
# Number of wrong results in production: 4
# No date keyword found for Hawaii in leisure
# Number of wrong results in leisure: 4
# Hawaii TEST: Kaʻohe State Lease
# --------------------------------------------------------------------------------
# Searching IOWA
# No date keyword found for Iowa in commercial
# Number of wrong results in commercial: 4
# No date keyword found for Iowa in service
# Number of wrong results in service: 4
# Number of wrong results in tourism: 5
# No date keyword found for Iowa in religion
# Number of wrong results in religion: 5
# Number of wrong results in beach: 6
# No date keyword found for Iowa in production
# Number of wrong results in production: 6
# No date keyword found for Iowa in leisure
# Number of wrong results in leisure: 6
# Iowa TEST: Lollar Park
# --------------------------------------------------------------------------------
# Searching IDAHO
# No date keyword found for Idaho in commercial
# Number of wrong results in commercial: 6
# No date keyword found for Idaho in service
# Number of wrong results in service: 6
# No date keyword found for Idaho in tourism
# Number of wrong results in tourism: 6
# No date keyword found for Idaho in religion
# Number of wrong results in religion: 6
# Number of wrong results in beach: 7
# No results found for Idaho in production
# --------------------------------------------------------------------------------
# Searching ILLINOIS
# No date keyword found for Illinois in commercial
# Number of wrong results in commercial: 7
# No date keyword found for Illinois in service
# Number of wrong results in service: 7
# No date keyword found for Illinois in tourism
# Number of wrong results in tourism: 7
# No date keyword found for Illinois in religion
# Number of wrong results in religion: 7
# No date keyword found for Illinois in beach
# Number of wrong results in beach: 7
# No date keyword found for Illinois in production
# Number of wrong results in production: 7
# No date keyword found for Illinois in leisure
# Number of wrong results in leisure: 7
# Illinois TEST: McClallen Memorial Park
# --------------------------------------------------------------------------------
# Searching INDIANA
# No date keyword found for Indiana in commercial
# Number of wrong results in commercial: 7
# No date keyword found for Indiana in service
# Number of wrong results in service: 7
# No date keyword found for Indiana in tourism
# Number of wrong results in tourism: 7
# No date keyword found for Indiana in religion
# Number of wrong results in religion: 7
# Number of wrong results in beach: 8
# No date keyword found for Indiana in production
# Number of wrong results in production: 8
# No date keyword found for Indiana in leisure
# Number of wrong results in leisure: 8
# Indiana TEST: Home Park
# --------------------------------------------------------------------------------
# Searching KANSAS
# No date keyword found for Kansas in commercial
# Number of wrong results in commercial: 8
# No date keyword found for Kansas in service
# Number of wrong results in service: 8
# No date keyword found for Kansas in tourism
# Number of wrong results in tourism: 8
# No date keyword found for Kansas in religion
# Number of wrong results in religion: 8
# Number of wrong results in beach: 9
# No date keyword found for Kansas in production
# Number of wrong results in production: 9
# No date keyword found for Kansas in leisure
# Number of wrong results in leisure: 9
# Kansas TEST: Wilson Recreation Area
# --------------------------------------------------------------------------------
# Searching KENTUCKY
# No date keyword found for Kentucky in commercial
# Number of wrong results in commercial: 9
# No date keyword found for Kentucky in service
# Number of wrong results in service: 9
# No date keyword found for Kentucky in tourism
# Number of wrong results in tourism: 9
# No date keyword found for Kentucky in religion
# Number of wrong results in religion: 9
# Number of wrong results in beach: 10
# No date keyword found for Kentucky in production
# Number of wrong results in production: 10
# No date keyword found for Kentucky in leisure
# Number of wrong results in leisure: 10
# Kentucky TEST: Fort Boonesborough State Park
# --------------------------------------------------------------------------------
# Searching LOUISIANA
# No date keyword found for Louisiana in commercial
# Number of wrong results in commercial: 10
# No date keyword found for Louisiana in service
# Number of wrong results in service: 10
# No date keyword found for Louisiana in tourism
# Number of wrong results in tourism: 10
# No date keyword found for Louisiana in religion
# Number of wrong results in religion: 10
# No results found for Louisiana in beach
# --------------------------------------------------------------------------------
# Searching MASSACHUSETTS
# No date keyword found for Massachusetts in commercial
# Number of wrong results in commercial: 10
# No date keyword found for Massachusetts in service
# Number of wrong results in service: 10
# No date keyword found for Massachusetts in tourism
# Number of wrong results in tourism: 10
# No date keyword found for Massachusetts in religion
# Number of wrong results in religion: 10
# Number of wrong results in beach: 11
# No date keyword found for Massachusetts in production
# Number of wrong results in production: 11
# No date keyword found for Massachusetts in leisure
# Number of wrong results in leisure: 11
# Massachusetts TEST: Concord Road, Sudbury, MA 01776, United States of America
# --------------------------------------------------------------------------------
# Searching MARYLAND
# No date keyword found for Maryland in commercial
# Number of wrong results in commercial: 11
# No date keyword found for Maryland in service
# Number of wrong results in service: 11
# Number of wrong results in tourism: 12
# No date keyword found for Maryland in religion
# Number of wrong results in religion: 12
# Number of wrong results in beach: 13
# No date keyword found for Maryland in production
# Number of wrong results in production: 13
# No date keyword found for Maryland in leisure
# Number of wrong results in leisure: 13
# Maryland TEST: Bacon Ridge Natural Area
# --------------------------------------------------------------------------------
# Searching MAINE
# No date keyword found for Maine in commercial
# Number of wrong results in commercial: 13
# No date keyword found for Maine in service
# Number of wrong results in service: 13
# No date keyword found for Maine in tourism
# Number of wrong results in tourism: 13
# No date keyword found for Maine in religion
# Number of wrong results in religion: 13
# Number of wrong results in beach: 14
# No date keyword found for Maine in production
# Number of wrong results in production: 14
# No date keyword found for Maine in leisure
# Number of wrong results in leisure: 14
# Maine TEST: Main Road, Abbot, ME 04406, United States of America
# --------------------------------------------------------------------------------
# Searching MICHIGAN
# No date keyword found for Michigan in commercial
# Number of wrong results in commercial: 14
# No date keyword found for Michigan in service
# Number of wrong results in service: 14
# No date keyword found for Michigan in tourism
# Number of wrong results in tourism: 14
# No date keyword found for Michigan in religion
# Number of wrong results in religion: 14
# Number of wrong results in beach: 15
# No results found for Michigan in production
# --------------------------------------------------------------------------------
# Searching MINNESOTA
# No date keyword found for Minnesota in commercial
# Number of wrong results in commercial: 15
# No date keyword found for Minnesota in service
# Number of wrong results in service: 15
# No date keyword found for Minnesota in tourism
# Number of wrong results in tourism: 15
# No date keyword found for Minnesota in religion
# Number of wrong results in religion: 15
# Number of wrong results in beach: 16
# No date keyword found for Minnesota in production
# Number of wrong results in production: 16
# No date keyword found for Minnesota in leisure
# Number of wrong results in leisure: 16
# Minnesota TEST: Foothills State Forest
# --------------------------------------------------------------------------------
# Searching MISSOURI
# No date keyword found for Missouri in commercial
# Number of wrong results in commercial: 16
# No date keyword found for Missouri in service
# Number of wrong results in service: 16
# Number of wrong results in tourism: 17
# No date keyword found for Missouri in religion
# Number of wrong results in religion: 17
# No results found for Missouri in beach
# --------------------------------------------------------------------------------
# Searching MISSISSIPPI
# No date keyword found for Mississippi in commercial
# Number of wrong results in commercial: 17
# No date keyword found for Mississippi in service
# Number of wrong results in service: 17
# No date keyword found for Mississippi in tourism
# Number of wrong results in tourism: 17
# No date keyword found for Mississippi in religion
# Number of wrong results in religion: 17
# No results found for Mississippi in beach
# --------------------------------------------------------------------------------
# Searching MONTANA
# No date keyword found for Montana in commercial
# Number of wrong results in commercial: 17
# No date keyword found for Montana in service
# Number of wrong results in service: 17
# No date keyword found for Montana in tourism
# Number of wrong results in tourism: 17
# No date keyword found for Montana in religion
# Number of wrong results in religion: 17
# No results found for Montana in beach
# --------------------------------------------------------------------------------
# Searching NORTH CAROLINA
# No date keyword found for North Carolina in commercial
# Number of wrong results in commercial: 17
# No date keyword found for North Carolina in service
# Number of wrong results in service: 17
# No date keyword found for North Carolina in tourism
# Number of wrong results in tourism: 17
# No date keyword found for North Carolina in religion
# Number of wrong results in religion: 17
# No date keyword found for North Carolina in beach
# Number of wrong results in beach: 17
# No date keyword found for North Carolina in production
# Number of wrong results in production: 17
# No date keyword found for North Carolina in leisure
# Number of wrong results in leisure: 17
# North Carolina TEST: New Hope Game Lands
# --------------------------------------------------------------------------------
# Searching NORTH DAKOTA
# No date keyword found for North Dakota in commercial
# Number of wrong results in commercial: 17
# No date keyword found for North Dakota in service
# Number of wrong results in service: 17
# No results found for North Dakota in tourism
# --------------------------------------------------------------------------------
# Searching NEBRASKA
# No date keyword found for Nebraska in commercial
# Number of wrong results in commercial: 17
# No date keyword found for Nebraska in service
# Number of wrong results in service: 17
# No date keyword found for Nebraska in tourism
# Number of wrong results in tourism: 17
# No date keyword found for Nebraska in religion
# Number of wrong results in religion: 17
# No results found for Nebraska in beach
# --------------------------------------------------------------------------------
# Searching NEW HAMPSHIRE
# No date keyword found for New Hampshire in commercial
# Number of wrong results in commercial: 17
# No date keyword found for New Hampshire in service
# Number of wrong results in service: 17
# No date keyword found for New Hampshire in tourism
# Number of wrong results in tourism: 17
# No date keyword found for New Hampshire in religion
# Number of wrong results in religion: 17
# Number of wrong results in beach: 18
# No date keyword found for New Hampshire in production
# Number of wrong results in production: 18
# No date keyword found for New Hampshire in leisure
# Number of wrong results in leisure: 18
# New Hampshire TEST: Pellican Alley, Concord, NH 03302, United States of America
# --------------------------------------------------------------------------------
# Searching NEW JERSEY
# No date keyword found for New Jersey in commercial
# Number of wrong results in commercial: 18
# No date keyword found for New Jersey in service
# Number of wrong results in service: 18
# No date keyword found for New Jersey in tourism
# Number of wrong results in tourism: 18
# No date keyword found for New Jersey in religion
# Number of wrong results in religion: 18
# Number of wrong results in beach: 19
# No date keyword found for New Jersey in production
# Number of wrong results in production: 19
# No date keyword found for New Jersey in leisure
# Number of wrong results in leisure: 19
# New Jersey TEST: New Jersey Pinelands National Reserve
# --------------------------------------------------------------------------------
# Searching NEW MEXICO
# No date keyword found for New Mexico in commercial
# Number of wrong results in commercial: 19
# No date keyword found for New Mexico in service
# Number of wrong results in service: 19
# Number of wrong results in tourism: 20
# No date keyword found for New Mexico in religion
# Number of wrong results in religion: 20
# No results found for New Mexico in beach
# --------------------------------------------------------------------------------
# Searching NEVADA
# No results found for Nevada in commercial
# --------------------------------------------------------------------------------
# Searching NEW YORK
# No date keyword found for New York in commercial
# Number of wrong results in commercial: 20
# No date keyword found for New York in service
# Number of wrong results in service: 20
# No date keyword found for New York in tourism
# Number of wrong results in tourism: 20
# No date keyword found for New York in religion
# Number of wrong results in religion: 20
# Number of wrong results in beach: 21
# No date keyword found for New York in production
# Number of wrong results in production: 21
# No date keyword found for New York in leisure
# Number of wrong results in leisure: 21
# New York TEST: Wilcox Lake Wild Forest
# --------------------------------------------------------------------------------
# Searching OHIO
# No date keyword found for Ohio in commercial
# Number of wrong results in commercial: 21
# No date keyword found for Ohio in service
# Number of wrong results in service: 21
# No date keyword found for Ohio in tourism
# Number of wrong results in tourism: 21
# No date keyword found for Ohio in religion
# Number of wrong results in religion: 21
# Number of wrong results in beach: 22
# No date keyword found for Ohio in production
# Number of wrong results in production: 22
# No date keyword found for Ohio in leisure
# Number of wrong results in leisure: 22
# Ohio TEST: Village of Ashley Park and Pool
# --------------------------------------------------------------------------------
# Searching OKLAHOMA
# No date keyword found for Oklahoma in commercial
# Number of wrong results in commercial: 22
# No date keyword found for Oklahoma in service
# Number of wrong results in service: 22
# No date keyword found for Oklahoma in tourism
# Number of wrong results in tourism: 22
# No date keyword found for Oklahoma in religion
# Number of wrong results in religion: 22
# No results found for Oklahoma in beach
# --------------------------------------------------------------------------------
# Searching OREGON
# No results found for Oregon in commercial
# --------------------------------------------------------------------------------
# Searching PENNSYLVANIA
# No date keyword found for Pennsylvania in commercial
# Number of wrong results in commercial: 22
# No date keyword found for Pennsylvania in service
# Number of wrong results in service: 22
# No date keyword found for Pennsylvania in tourism
# Number of wrong results in tourism: 22
# No date keyword found for Pennsylvania in religion
# Number of wrong results in religion: 22
# Number of wrong results in beach: 23
# No date keyword found for Pennsylvania in production
# Number of wrong results in production: 23
# No date keyword found for Pennsylvania in leisure
# Number of wrong results in leisure: 23
# Pennsylvania TEST: Tiadaghton State Forest
# --------------------------------------------------------------------------------
# Searching RHODE ISLAND
# No date keyword found for Rhode Island in commercial
# Number of wrong results in commercial: 23
# No date keyword found for Rhode Island in service
# Number of wrong results in service: 23
# No date keyword found for Rhode Island in tourism
# Number of wrong results in tourism: 23
# No date keyword found for Rhode Island in religion
# Number of wrong results in religion: 23
# Number of wrong results in beach: 24
# No date keyword found for Rhode Island in production
# Number of wrong results in production: 24
# No date keyword found for Rhode Island in leisure
# Number of wrong results in leisure: 24
# Rhode Island TEST: Cocumcussoc Park
# --------------------------------------------------------------------------------
# Searching SOUTH CAROLINA
# No date keyword found for South Carolina in commercial
# Number of wrong results in commercial: 24
# No date keyword found for South Carolina in service
# Number of wrong results in service: 24
# Number of wrong results in tourism: 25
# No date keyword found for South Carolina in religion
# Number of wrong results in religion: 25
# Number of wrong results in beach: 26
# No date keyword found for South Carolina in production
# Number of wrong results in production: 26
# No date keyword found for South Carolina in leisure
# Number of wrong results in leisure: 26
# South Carolina TEST: Peachtree Rock Heritage Preserve
# --------------------------------------------------------------------------------
# Searching SOUTH DAKOTA
# No date keyword found for South Dakota in commercial
# Number of wrong results in commercial: 26
# No date keyword found for South Dakota in service
# Number of wrong results in service: 26
# No results found for South Dakota in tourism
# --------------------------------------------------------------------------------
# Searching TENNESSEE
# No date keyword found for Tennessee in commercial
# Number of wrong results in commercial: 26
# No date keyword found for Tennessee in service
# Number of wrong results in service: 26
# No date keyword found for Tennessee in tourism
# Number of wrong results in tourism: 26
# No date keyword found for Tennessee in religion
# Number of wrong results in religion: 26
# Number of wrong results in beach: 27
# No date keyword found for Tennessee in production
# Number of wrong results in production: 27
# No date keyword found for Tennessee in leisure
# Number of wrong results in leisure: 27
# Tennessee TEST: Daisye Musgrave Hulan Park
# --------------------------------------------------------------------------------
# Searching TEXAS
# No date keyword found for Texas in commercial
# Number of wrong results in commercial: 27
# No date keyword found for Texas in service
# Number of wrong results in service: 27
# No date keyword found for Texas in tourism
# Number of wrong results in tourism: 27
# No date keyword found for Texas in religion
# Number of wrong results in religion: 27
# No results found for Texas in beach
# --------------------------------------------------------------------------------
# Searching UTAH
# No date keyword found for Utah in commercial
# Number of wrong results in commercial: 27
# No date keyword found for Utah in service
# Number of wrong results in service: 27
# No date keyword found for Utah in tourism
# Number of wrong results in tourism: 27
# No date keyword found for Utah in religion
# Number of wrong results in religion: 27
# Number of wrong results in beach: 28
# No results found for Utah in production
# --------------------------------------------------------------------------------
# Searching VIRGINIA
# No date keyword found for Virginia in commercial
# Number of wrong results in commercial: 28
# No date keyword found for Virginia in service
# Number of wrong results in service: 28
# No date keyword found for Virginia in tourism
# Number of wrong results in tourism: 28
# No date keyword found for Virginia in religion
# Number of wrong results in religion: 28
# Number of wrong results in beach: 29
# No date keyword found for Virginia in production
# Number of wrong results in production: 29
# No date keyword found for Virginia in leisure
# Number of wrong results in leisure: 29
# Virginia TEST: Appomattox-Buckingham State Forest
# --------------------------------------------------------------------------------
# Searching VERMONT
# No date keyword found for Vermont in commercial
# Number of wrong results in commercial: 29
# No date keyword found for Vermont in service
# Number of wrong results in service: 29
# No date keyword found for Vermont in tourism
# Number of wrong results in tourism: 29
# No date keyword found for Vermont in religion
# Number of wrong results in religion: 29
# No date keyword found for Vermont in beach
# Number of wrong results in beach: 29
# No date keyword found for Vermont in production
# Number of wrong results in production: 29
# No date keyword found for Vermont in leisure
# Number of wrong results in leisure: 29
# Vermont TEST: Village Green
# --------------------------------------------------------------------------------
# Searching WASHINGTON
# No date keyword found for Washington in commercial
# Number of wrong results in commercial: 29
# No date keyword found for Washington in service
# Number of wrong results in service: 29
# No date keyword found for Washington in tourism
# Number of wrong results in tourism: 29
# No date keyword found for Washington in religion
# Number of wrong results in religion: 29
# Number of wrong results in beach: 30
# No date keyword found for Washington in production
# Number of wrong results in production: 30
# No date keyword found for Washington in leisure
# Number of wrong results in leisure: 30
# Washington TEST: Winton Road, Winton, WA, United States of America
# --------------------------------------------------------------------------------
# Searching WISCONSIN
# No date keyword found for Wisconsin in commercial
# Number of wrong results in commercial: 30
# No date keyword found for Wisconsin in service
# Number of wrong results in service: 30
# No date keyword found for Wisconsin in tourism
# Number of wrong results in tourism: 30
# Number of wrong results in religion: 31
# Number of wrong results in beach: 32
# No date keyword found for Wisconsin in production
# Number of wrong results in production: 32
# No date keyword found for Wisconsin in leisure
# Number of wrong results in leisure: 32
# Wisconsin TEST: Brandon Community Park
# --------------------------------------------------------------------------------
# Searching WEST VIRGINIA
# No date keyword found for West Virginia in commercial
# Number of wrong results in commercial: 32
# No date keyword found for West Virginia in service
# Number of wrong results in service: 32
# No date keyword found for West Virginia in tourism
# Number of wrong results in tourism: 32
# No date keyword found for West Virginia in religion
# Number of wrong results in religion: 32
# No date keyword found for West Virginia in beach
# Number of wrong results in beach: 32
# No date keyword found for West Virginia in production
# Number of wrong results in production: 32
# No date keyword found for West Virginia in leisure
# Number of wrong results in leisure: 32
# West Virginia TEST: Elk River Wildlife Management Area
# --------------------------------------------------------------------------------
# Searching WYOMING
# No date keyword found for Wyoming in commercial
# Number of wrong results in commercial: 32
# No date keyword found for Wyoming in service
# Number of wrong results in service: 32
# No date keyword found for Wyoming in tourism
# Number of wrong results in tourism: 32
# No results found for Wyoming in religion
# --------------------------------------------------------------------------------
# Ending Services Search
# Number of states with missing data: 20

# %%
# RUNNING THIS CELL WILL COPY THE states_df AND PERFORM A RANDOM NUMBER SAMPLING

states_popularity_df = states_df.copy()

# Pick the columns with the popularity for each category searched
states_popularity_df = states_popularity_df[['state', 'name', 'commercial_popularity', 'service_popularity', 'religion_popularity', 'tourism_popularity', 'production_popularity', 'leisure_popularity']]

for index, row in states_popularity_df.iterrows():
    count_nan = 0
    for pop in states_popularity_df.columns[2:]:
        if np.isnan(states_popularity_df.loc[index, pop]):
            states_popularity_df.at[index, pop] = random.uniform(0, states_popularity_df.loc[:, pop].max() / 5)
            count_nan += 1   
    print(f"Number of NaN values for {states_popularity_df.loc[index, 'name']}: {count_nan}")

states_popularity_df.head()
# Out:
# Number of NaN values for Alaska: 6
# Number of NaN values for Alabama: 3
# Number of NaN values for Arkansas: 0
# Number of NaN values for Arizona: 2
# Number of NaN values for California: 0
# Number of NaN values for Colorado: 0
# Number of NaN values for Connecticut: 0
# Number of NaN values for Delaware: 0
# Number of NaN values for Florida: 0
# Number of NaN values for Georgia: 2
# Number of NaN values for Hawaii: 0
# Number of NaN values for Iowa: 1
# Number of NaN values for Idaho: 2
# Number of NaN values for Illinois: 0
# Number of NaN values for Indiana: 0
# Number of NaN values for Kansas: 0
# Number of NaN values for Kentucky: 0
# Number of NaN values for Louisiana: 2
# Number of NaN values for Massachusetts: 0
# Number of NaN values for Maryland: 1
# Number of NaN values for Maine: 0
# Number of NaN values for Michigan: 2
# Number of NaN values for Minnesota: 0
# Number of NaN values for Missouri: 3
# Number of NaN values for Mississippi: 2
# Number of NaN values for Montana: 2
# Number of NaN values for North Carolina: 0
# Number of NaN values for North Dakota: 4
# Number of NaN values for Nebraska: 2
# Number of NaN values for New Hampshire: 0
# Number of NaN values for New Jersey: 0
# Number of NaN values for New Mexico: 3
# Number of NaN values for Nevada: 6
# Number of NaN values for New York: 0
# Number of NaN values for Ohio: 0
# Number of NaN values for Oklahoma: 2
# Number of NaN values for Oregon: 6
# Number of NaN values for Pennsylvania: 0
# Number of NaN values for Rhode Island: 0
# Number of NaN values for South Carolina: 1
# Number of NaN values for South Dakota: 4
# Number of NaN values for Tennessee: 0
# Number of NaN values for Texas: 2
# Number of NaN values for Utah: 2
# Number of NaN values for Virginia: 0
# Number of NaN values for Vermont: 0
# Number of NaN values for Washington: 0
# Number of NaN values for Wisconsin: 1
# Number of NaN values for West Virginia: 0
# Number of NaN values for Wyoming: 3
#   state        name  commercial_popularity  service_popularity  \
# 0    AK      Alaska               0.080008            0.030888
# 1    AL     Alabama               0.000000            0.000000
# 2    AR    Arkansas               0.000000            0.000000
# 3    AZ     Arizona               0.000000            0.000000
# 4    CA  California               0.821187            0.000000
#
#    religion_popularity  tourism_popularity  production_popularity  \
# 0             0.115833            0.201822               0.083749
# 1             0.000000            0.213146               0.206775
# 2             0.742974            0.770750               0.760664
# 3             0.000000            0.000000               0.413324
# 4             0.000000            1.076621               0.000000
#
#    leisure_popularity
# 0            0.019388
# 1            0.260133
# 2            0.760625
# 3            0.179727
# 4            0.000000

# %% [markdown]
# # Test Request Below

# %%
# test_places_url = 'https://api.geoapify.com/v2/places?'

# # Select the categories that you want to search and test it in California
# test_params = {
#             "categories": "beach",
#             "apiKey": api_key,
#             "limit": 10,
#             "filter": f"rect:{states_df['lon1'][4]},{states_df['lat1'][4]},{states_df['lon2'][4]},{states_df['lat2'][4]}",
#         }
# test_json = requests.get(test_places_url, params=test_params).json()
# # print(json.dumps(test_json, indent= 4, sort_keys=True))

# test_data = []
# for feature in test_json['features']:
#     test_placeID = feature['properties']['place_id']
#     test_geocode_url = 'https://api.geoapify.com/v1/geocode/search?'
#     try:
#         test_params_geocode = {
#                 "apiKey": api_key,
#                 "text": feature['properties']['formatted'],
#                 "limit": 1,
#                 "filter": f"place:{test_placeID}",
#             }
#     except KeyError:
#         test_params_geocode = {
#                 "apiKey": api_key,
#                 "text": feature['properties']['categories'],
#                 "limit": 1,
#                 "filter": f"place:{test_placeID}",
#             }
#     test_geocode_json = requests.get(test_geocode_url, params=test_params_geocode).json()
#     for geo_feature in test_geocode_json['features']:
#         if ((geo_feature['properties']['rank']['confidence'] == 1) | (geo_feature['properties']['rank']['match_type'] == "full_match") | (geo_feature['properties']['rank']['match_type'] == "match_by_building")):
#             try:
#                 test_data.append(geo_feature['properties']['rank']['popularity'])
#                 print(geo_feature['properties']['rank']['popularity'])
#             except KeyError:
#                 test_data.append(None)
        
#     print(json.dumps(test_geocode_json, indent= 4, sort_keys=True))
# Out:
# {
#     "features": [
#         {
#             "bbox": [
#                 -118.9015576,
#                 36.787263,
#                 -118.9006472,
#                 36.7885309
#             ],
#             "geometry": {
#                 "coordinates": [
#                     -118.90095516756642,
#                     36.7878554
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Sandy Cove Beach",
#                 "address_line2": "Fresno County, CA, United States of America",
#                 "category": "beach",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Fresno County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "formatted": "Sandy Cove Beach, Fresno County, CA, United States of America",
#                 "lat": 36.7878554,
#                 "lon": -118.90095516756642,
#                 "name": "Sandy Cove Beach",
#                 "place_id": "510af7dc3fa9b95dc0590e7d1c72d8644240f00102f901778fba1200000000c0020192031053616e647920436f7665204265616368",
#                 "plus_code": "8583Q3QX+4J",
#                 "rank": {
#                     "confidence": 0.7290000000000001,
#                     "confidence_city_level": 0.9,
#                     "confidence_street_level": 0.7290000000000001,
#                     "importance": 0.2000099999999999,
#                     "match_type": "inner_part"
#                 },
#                 "result_type": "amenity",
#                 "state": "California",
#                 "state_code": "CA",
#                 "timezone": {
#                     "abbreviation_DST": "PDT",
#                     "abbreviation_STD": "PST",
#                     "name": "America/Los_Angeles",
#                     "offset_DST": "-07:00",
#                     "offset_DST_seconds": -25200,
#                     "offset_STD": "-08:00",
#                     "offset_STD_seconds": -28800
#                 }
#             },
#             "type": "Feature"
#         }
#     ],
#     "query": {
#         "parsed": {
#             "city": "cove beach",
#             "country": "united states of america",
#             "county": "fresno county",
#             "expected_type": "street",
#             "state": "california",
#             "street": "sandy"
#         },
#         "text": "Sandy Cove Beach, Fresno County, California, United States of America"
#     },
#     "type": "FeatureCollection"
# }
# 1.1837504212494745
# {
#     "features": [
#         {
#             "bbox": [
#                 -119.1357557,
#                 38.0148737,
#                 -119.1356557,
#                 38.0149737
#             ],
#             "geometry": {
#                 "coordinates": [
#                     -119.1357057,
#                     38.0149237
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Danburg Beach",
#                 "address_line2": "Mono County, CA, United States of America",
#                 "category": "beach",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Mono County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "formatted": "Danburg Beach, Mono County, CA, United States of America",
#                 "lat": 38.0149237,
#                 "lon": -119.1357057,
#                 "name": "Danburg Beach",
#                 "place_id": "515fd8f566afc85dc059b8b71105e9014340f00103f901acd0621500000000c0020192030d44616e62757267204265616368",
#                 "plus_code": "85C22V77+XP",
#                 "rank": {
#                     "confidence": 1,
#                     "confidence_city_level": 1,
#                     "importance": 0.4000099999999999,
#                     "match_type": "inner_part",
#                     "popularity": 1.1837504212494745
#                 },
#                 "result_type": "amenity",
#                 "state": "California",
#                 "state_code": "CA",
#                 "timezone": {
#                     "abbreviation_DST": "PDT",
#                     "abbreviation_STD": "PST",
#                     "name": "America/Los_Angeles",
#                     "offset_DST": "-07:00",
#                     "offset_DST_seconds": -25200,
#                     "offset_STD": "-08:00",
#                     "offset_STD_seconds": -28800
#                 }
#             },
#             "type": "Feature"
#         }
#     ],
#     "query": {
#         "parsed": {
#             "city": "danburg beach",
#             "country": "united states of america",
#             "county": "mono county",
#             "expected_type": "city",
#             "state": "california"
#         },
#         "text": "Danburg Beach, Mono County, California, United States of America"
#     },
#     "type": "FeatureCollection"
# }
# 1.1973385967826011
# {
#     "features": [
#         {
#             "bbox": [
#                 -119.0196397,
#                 37.941543,
#                 -119.0195397,
#                 37.941643
#             ],
#             "geometry": {
#                 "coordinates": [
#                     -119.0195897,
#                     37.941593
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Navy Beach",
#                 "address_line2": "Mono County, CA, United States of America",
#                 "category": "beach",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Mono County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "formatted": "Navy Beach, Mono County, CA, United States of America",
#                 "lat": 37.941593,
#                 "lon": -119.0195897,
#                 "name": "Navy Beach",
#                 "place_id": "51a93528f540c15dc0593e92921e86f84240f00103f9016d62631500000000c0020192030a4e617679204265616368",
#                 "plus_code": "8592WXRJ+J5",
#                 "rank": {
#                     "confidence": 1,
#                     "confidence_city_level": 1,
#                     "importance": 0.4000099999999999,
#                     "match_type": "inner_part",
#                     "popularity": 1.1973385967826011
#                 },
#                 "result_type": "amenity",
#                 "state": "California",
#                 "state_code": "CA",
#                 "timezone": {
#                     "abbreviation_DST": "PDT",
#                     "abbreviation_STD": "PST",
#                     "name": "America/Los_Angeles",
#                     "offset_DST": "-07:00",
#                     "offset_DST_seconds": -25200,
#                     "offset_STD": "-08:00",
#                     "offset_STD_seconds": -28800
#                 }
#             },
#             "type": "Feature"
#         }
#     ],
#     "query": {
#         "parsed": {
#             "city": "navy beach",
#             "country": "united states of america",
#             "county": "mono county",
#             "expected_type": "city",
#             "state": "california"
#         },
#         "text": "Navy Beach, Mono County, California, United States of America"
#     },
#     "type": "FeatureCollection"
# }
# 1.2697838573077804
# {
#     "features": [
#         {
#             "bbox": [
#                 -119.071261,
#                 37.7927312,
#                 -119.0648943,
#                 37.7963324
#             ],
#             "geometry": {
#                 "coordinates": [
#                     -119.06637520833979,
#                     37.7945524
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "June Lake Beach",
#                 "address_line2": "Mono County, CA, United States of America",
#                 "category": "beach",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Mono County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "formatted": "June Lake Beach, Mono County, CA, United States of America",
#                 "lat": 37.7945524,
#                 "lon": -119.06637520833979,
#                 "name": "June Lake Beach",
#                 "place_id": "516a45cd7d3fc45dc059aa7a9ee4b3e54240f00102f901cb4c291900000000c0020192030f4a756e65204c616b65204265616368",
#                 "plus_code": "8592QWVM+RC",
#                 "rank": {
#                     "confidence": 0.7290000000000001,
#                     "confidence_city_level": 0.9,
#                     "importance": 0.2000099999999999,
#                     "match_type": "full_match",
#                     "popularity": 1.2697838573077804
#                 },
#                 "result_type": "amenity",
#                 "state": "California",
#                 "state_code": "CA",
#                 "timezone": {
#                     "abbreviation_DST": "PDT",
#                     "abbreviation_STD": "PST",
#                     "name": "America/Los_Angeles",
#                     "offset_DST": "-07:00",
#                     "offset_DST_seconds": -25200,
#                     "offset_STD": "-08:00",
#                     "offset_STD_seconds": -28800
#                 }
#             },
#             "type": "Feature"
#         }
#     ],
#     "query": {
#         "parsed": {
#             "city": "lake beach",
#             "country": "united states of america",
#             "county": "mono county",
#             "expected_type": "amenity",
#             "house": "june",
#             "state": "california"
#         },
#         "text": "June Lake Beach, Mono County, California, United States of America"
#     },
#     "type": "FeatureCollection"
# }
# 1.2380643557586175
# {
#     "features": [
#         {
#             "bbox": [
#                 -118.9082483,
#                 36.7889722,
#                 -118.9081483,
#                 36.7890722
#             ],
#             "geometry": {
#                 "coordinates": [
#                     -118.9081983,
#                     36.7890222
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Jumping Rock",
#                 "address_line2": "Hume, CA 93628, United States of America",
#                 "category": "beach",
#                 "city": "Hume",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Fresno County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "formatted": "Jumping Rock, Hume, CA 93628, United States of America",
#                 "lat": 36.7890222,
#                 "lon": -118.9081983,
#                 "name": "Jumping Rock",
#                 "place_id": "511932c3eb1fba5dc059b368f0adfe644240f00103f9015628004e02000000c0020192030c4a756d70696e6720526f636b",
#                 "plus_code": "8583Q3QR+JP",
#                 "postcode": "93628",
#                 "rank": {
#                     "confidence": 1,
#                     "confidence_city_level": 1,
#                     "importance": 0.51001,
#                     "match_type": "full_match",
#                     "popularity": 1.2380643557586175
#                 },
#                 "result_type": "amenity",
#                 "state": "California",
#                 "state_code": "CA",
#                 "timezone": {
#                     "abbreviation_DST": "PDT",
#                     "abbreviation_STD": "PST",
#                     "name": "America/Los_Angeles",
#                     "offset_DST": "-07:00",
#                     "offset_DST_seconds": -25200,
#                     "offset_STD": "-08:00",
#                     "offset_STD_seconds": -28800
#                 }
#             },
#             "type": "Feature"
#         }
#     ],
#     "query": {
#         "parsed": {
#             "city": "hume",
#             "country": "united states of america",
#             "expected_type": "amenity",
#             "house": "jumping rock",
#             "postcode": "93628",
#             "state": "ca"
#         },
#         "text": "Jumping Rock, Hume, CA 93628, United States of America"
#     },
#     "type": "FeatureCollection"
# }
# 1.4770273001902179
# {
#     "features": [
#         {
#             "bbox": [
#                 -92.9790682,
#                 37.4111559,
#                 -92.9390682,
#                 37.4511559
#             ],
#             "geometry": {
#                 "coordinates": [
#                     -92.9590682,
#                     37.4311559
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Beach, MO",
#                 "address_line2": "United States of America",
#                 "category": "populated_place",
#                 "city": "Beach",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Webster County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "formatted": "Beach, MO, United States of America",
#                 "hamlet": "Beach",
#                 "lat": 37.4311559,
#                 "lon": -92.9590682,
#                 "name": "Beach",
#                 "place_id": "518d68965f613d57c0591dfdd41d30b74240f00103f90118bc070900000000c002089203054265616368",
#                 "plus_code": "8699C2JR+F9",
#                 "rank": {
#                     "confidence": 1,
#                     "confidence_city_level": 1,
#                     "importance": 0.35000999999999993,
#                     "match_type": "full_match",
#                     "popularity": 1.4770273001902179
#                 },
#                 "result_type": "city",
#                 "state": "Missouri",
#                 "state_code": "MO",
#                 "timezone": {
#                     "abbreviation_DST": "CDT",
#                     "abbreviation_STD": "CST",
#                     "name": "America/Chicago",
#                     "offset_DST": "-05:00",
#                     "offset_DST_seconds": -18000,
#                     "offset_STD": "-06:00",
#                     "offset_STD_seconds": -21600
#                 }
#             },
#             "type": "Feature"
#         }
#     ],
#     "query": {
#         "parsed": {
#             "city": "beach",
#             "expected_type": "unknown"
#         },
#         "text": "beach"
#     },
#     "type": "FeatureCollection"
# }
# 1.4770273001902179
# {
#     "features": [
#         {
#             "bbox": [
#                 -92.9790682,
#                 37.4111559,
#                 -92.9390682,
#                 37.4511559
#             ],
#             "geometry": {
#                 "coordinates": [
#                     -92.9590682,
#                     37.4311559
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Beach, MO",
#                 "address_line2": "United States of America",
#                 "category": "populated_place",
#                 "city": "Beach",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Webster County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "formatted": "Beach, MO, United States of America",
#                 "hamlet": "Beach",
#                 "lat": 37.4311559,
#                 "lon": -92.9590682,
#                 "name": "Beach",
#                 "place_id": "518d68965f613d57c0591dfdd41d30b74240f00103f90118bc070900000000c002089203054265616368",
#                 "plus_code": "8699C2JR+F9",
#                 "rank": {
#                     "confidence": 1,
#                     "confidence_city_level": 1,
#                     "importance": 0.35000999999999993,
#                     "match_type": "full_match",
#                     "popularity": 1.4770273001902179
#                 },
#                 "result_type": "city",
#                 "state": "Missouri",
#                 "state_code": "MO",
#                 "timezone": {
#                     "abbreviation_DST": "CDT",
#                     "abbreviation_STD": "CST",
#                     "name": "America/Chicago",
#                     "offset_DST": "-05:00",
#                     "offset_DST_seconds": -18000,
#                     "offset_STD": "-06:00",
#                     "offset_STD_seconds": -21600
#                 }
#             },
#             "type": "Feature"
#         }
#     ],
#     "query": {
#         "parsed": {
#             "city": "beach",
#             "expected_type": "unknown"
#         },
#         "text": "beach"
#     },
#     "type": "FeatureCollection"
# }
# 1.4770273001902179
# {
#     "features": [
#         {
#             "bbox": [
#                 -92.9790682,
#                 37.4111559,
#                 -92.9390682,
#                 37.4511559
#             ],
#             "geometry": {
#                 "coordinates": [
#                     -92.9590682,
#                     37.4311559
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Beach, MO",
#                 "address_line2": "United States of America",
#                 "category": "populated_place",
#                 "city": "Beach",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Webster County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "formatted": "Beach, MO, United States of America",
#                 "hamlet": "Beach",
#                 "lat": 37.4311559,
#                 "lon": -92.9590682,
#                 "name": "Beach",
#                 "place_id": "518d68965f613d57c0591dfdd41d30b74240f00103f90118bc070900000000c002089203054265616368",
#                 "plus_code": "8699C2JR+F9",
#                 "rank": {
#                     "confidence": 1,
#                     "confidence_city_level": 1,
#                     "importance": 0.35000999999999993,
#                     "match_type": "full_match",
#                     "popularity": 1.4770273001902179
#                 },
#                 "result_type": "city",
#                 "state": "Missouri",
#                 "state_code": "MO",
#                 "timezone": {
#                     "abbreviation_DST": "CDT",
#                     "abbreviation_STD": "CST",
#                     "name": "America/Chicago",
#                     "offset_DST": "-05:00",
#                     "offset_DST_seconds": -18000,
#                     "offset_STD": "-06:00",
#                     "offset_STD_seconds": -21600
#                 }
#             },
#             "type": "Feature"
#         }
#     ],
#     "query": {
#         "parsed": {
#             "city": "beach",
#             "expected_type": "unknown"
#         },
#         "text": "beach"
#     },
#     "type": "FeatureCollection"
# }
# 1.4770273001902179
# {
#     "features": [
#         {
#             "bbox": [
#                 -92.9790682,
#                 37.4111559,
#                 -92.9390682,
#                 37.4511559
#             ],
#             "geometry": {
#                 "coordinates": [
#                     -92.9590682,
#                     37.4311559
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Beach, MO",
#                 "address_line2": "United States of America",
#                 "category": "populated_place",
#                 "city": "Beach",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Webster County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "formatted": "Beach, MO, United States of America",
#                 "hamlet": "Beach",
#                 "lat": 37.4311559,
#                 "lon": -92.9590682,
#                 "name": "Beach",
#                 "place_id": "518d68965f613d57c0591dfdd41d30b74240f00103f90118bc070900000000c002089203054265616368",
#                 "plus_code": "8699C2JR+F9",
#                 "rank": {
#                     "confidence": 1,
#                     "confidence_city_level": 1,
#                     "importance": 0.35000999999999993,
#                     "match_type": "full_match",
#                     "popularity": 1.4770273001902179
#                 },
#                 "result_type": "city",
#                 "state": "Missouri",
#                 "state_code": "MO",
#                 "timezone": {
#                     "abbreviation_DST": "CDT",
#                     "abbreviation_STD": "CST",
#                     "name": "America/Chicago",
#                     "offset_DST": "-05:00",
#                     "offset_DST_seconds": -18000,
#                     "offset_STD": "-06:00",
#                     "offset_STD_seconds": -21600
#                 }
#             },
#             "type": "Feature"
#         }
#     ],
#     "query": {
#         "parsed": {
#             "city": "beach",
#             "expected_type": "unknown"
#         },
#         "text": "beach"
#     },
#     "type": "FeatureCollection"
# }
# 1.4770273001902179
# {
#     "features": [
#         {
#             "bbox": [
#                 -92.9790682,
#                 37.4111559,
#                 -92.9390682,
#                 37.4511559
#             ],
#             "geometry": {
#                 "coordinates": [
#                     -92.9590682,
#                     37.4311559
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Beach, MO",
#                 "address_line2": "United States of America",
#                 "category": "populated_place",
#                 "city": "Beach",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Webster County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "formatted": "Beach, MO, United States of America",
#                 "hamlet": "Beach",
#                 "lat": 37.4311559,
#                 "lon": -92.9590682,
#                 "name": "Beach",
#                 "place_id": "518d68965f613d57c0591dfdd41d30b74240f00103f90118bc070900000000c002089203054265616368",
#                 "plus_code": "8699C2JR+F9",
#                 "rank": {
#                     "confidence": 1,
#                     "confidence_city_level": 1,
#                     "importance": 0.35000999999999993,
#                     "match_type": "full_match",
#                     "popularity": 1.4770273001902179
#                 },
#                 "result_type": "city",
#                 "state": "Missouri",
#                 "state_code": "MO",
#                 "timezone": {
#                     "abbreviation_DST": "CDT",
#                     "abbreviation_STD": "CST",
#                     "name": "America/Chicago",
#                     "offset_DST": "-05:00",
#                     "offset_DST_seconds": -18000,
#                     "offset_STD": "-06:00",
#                     "offset_STD_seconds": -21600
#                 }
#             },
#             "type": "Feature"
#         }
#     ],
#     "query": {
#         "parsed": {
#             "city": "beach",
#             "expected_type": "unknown"
#         },
#         "text": "beach"
#     },
#     "type": "FeatureCollection"
# }
