# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json
import random

# Import API key
from geoapify_key import api_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Read states.csv and create it as a Dataframe
states_loc = pd.read_csv('../states.csv')
states_loc_df = pd.DataFrame(states_loc)
states_loc_df.head()
# Out:
#   state   latitude   longitude        name
# 0    AK  63.588753 -154.493062      Alaska
# 1    AL  32.318231  -86.902298     Alabama
# 2    AR  35.201050  -91.831833    Arkansas
# 3    AZ  34.048928 -111.093731     Arizona
# 4    CA  36.778261 -119.417932  California

# %%
# Read states_area.csv and merge with states.csv
states_area = pd.read_csv('../states_area.csv')
states_area_df = pd.DataFrame(states_area)

# Format Dataframe for same column name and area values to int
states_area_df.rename(columns={"state": "name", 
                               "Total Area (sq km)": "area (sq km)"}, 
                               inplace=True)
states_area_df['area (sq km)'] = [int(area.replace(",", "")) for area in states_area_df['area (sq km)']]
states_df = pd.merge(states_loc_df,states_area_df, on='name')
states_df.head()
# Out:
#   state   latitude   longitude        name  area (sq km)        lon1  \
# 0    AK  63.588753 -154.493062      Alaska       1723337 -130.000000
# 1    AL  32.318231  -86.902298     Alabama        135767  -84.883333
# 2    AR  35.201050  -91.831833    Arkansas        137732  -89.650000
# 3    AZ  34.048928 -111.093731     Arizona        295234 -109.050000
# 4    CA  36.778261 -119.417932  California        423967 -114.133333
#
#         lat1        lon2       lat2
# 0  51.333333  172.000000  71.833333
# 1  30.183333  -88.466667  35.000000
# 2  33.000000  -94.616667  36.500000
# 3  31.333333 -114.816667  37.000000
# 4  32.533333 -124.433333  42.000000

# %%
# Set base URLs for Places API and Geocode API
places_url = 'https://api.geoapify.com/v2/places?'
geocode_url = 'https://api.geoapify.com/v1/geocode/search?'

# Select the categories to search and set columns for them
categories_interested = ["commercial", "service", "tourism", "religion", "beach", "production", "leisure"]
for category in categories_interested:
    states_df[category] = None

# Counter for number of states with no data in a given category
states_missing = 0

# Initialize API search
print("Starting Services Search")
print('-'*80)

for index, row in states_df.iterrows():
    
    print(f"Searching {states_df.loc[index, 'name'].upper()}")
    # Get coordinate values for filter and bias parameters
    longitude = row['longitude']
    latitude = row['latitude']
    lon1 = row['lon1']
    lat1 = row['lat1']
    lon2 = row['lon2']
    lat2 = row['lat2']
    for category in categories_interested:
        
        # Set parameters for Places API response
        params = {
            "categories": category,
            "apiKey": api_key,
            "limit": 10,
            "filter": f"rect:{lon1},{lat1},{lon2},{lat2}",
            "bias": f"proximity:{longitude},{latitude}"
        }
        places_json = requests.get(places_url, params=params).json()

        # Check the returned list and break if the length is 0
        if int(len(places_json["features"])) == 0:
            print(f"No results found for {states_df.loc[index, 'name']} in {category}")
            print('-'*80)
            states_missing += 1
            break
        else:
        
            # Counter for number of results with mismatch in state
            result_wrong = 0

            # Check that the place is in the respective state
            for result in places_json['features']:
                try:
                    if result['properties']['state'] != states_df.loc[index, 'name']:
                        print(f"{result['properties']['state']} is not in the state of {states_df.loc[index, 'name']}!")
                        result_wrong += 1
                        break
                
                except:
                    result_wrong += 1
                    break
                else:
                    
                    # Use the Geocode API with place_id to obtain popularity index
                    for geo_result in places_json['features']:
                        place_id = geo_result['properties']['place_id']
                        try:
                            geo_params = {
                                    "apiKey": api_key,
                                    "text": geo_result['properties']['formatted'],
                                    "limit": 2,
                                    "filter": f"place:{place_id}",
                                }
                        
                        except KeyError:
                            geo_params = {
                                    "apiKey": api_key,
                                    "state": result['properties']['state_code'],
                                    "limit": 2,
                                    "filter": f"place:{place_id}",
                                }
                        geocode_json = requests.get(geocode_url, params=geo_params).json()
                        
                        # Setup average popularity list
                        geo_popularity = [0]
                        for geo_feature in geocode_json['features']:
                            if ((geo_feature['properties']['rank']['confidence'] == 1) | (geo_feature['properties']['rank']['match_type'] == "full_match") | (geo_feature['properties']['rank']['match_type'] == "inner_part")):
                                try:
                                    geo_popularity.append(float(geo_feature['properties']['rank']['popularity']))
                                    
                                    if float(geo_feature['properties']['rank']['popularity']) > max(geo_popularity):
                                        max_popularity = float(geo_feature['properties']['rank']['popularity'])
                                    min_popularity = float(geo_feature['properties']['rank']['popularity'])
                                
                                except KeyError:
                                    geo_popularity.append(0)

                        try:
                            states_df.loc[index, f'{category}_popularity'] = sum(geo_popularity) / len(geo_popularity)
                        
                        except ZeroDivisionError:
                            continue
                    
            try:
                states_df.loc[index, category] = places_json['features'][0]['properties']['name']
            except KeyError:
                try:
                    states_df.loc[index, category] = places_json['features'][0]['properties']['formatted']
                except KeyError:    
                    states_df.loc[index, category] = None
            if result_wrong != 0:
                print(f'Number of wrong results in {category}: {result_wrong}')
            
    else:
        print('-'*80)
        continue

print("Ending Services Search")
print(f"Number of Places API response with no data: {states_missing}")

empty_cols = [col for col in states_df.columns if ((states_df[col].isnull().all()) | (states_df[col].all() == None) | (states_df[col].count() < 25))]
states_df.drop(empty_cols, axis= 1, inplace=True)
# Out:
# Starting Services Search
# --------------------------------------------------------------------------------
# Searching ALASKA
# No results found for Alaska in commercial
# --------------------------------------------------------------------------------
# Searching ALABAMA
# Number of wrong results in tourism: 1
# No results found for Alabama in beach
# --------------------------------------------------------------------------------
# Searching ARKANSAS
# Number of wrong results in religion: 1
# --------------------------------------------------------------------------------
# Searching ARIZONA
# Number of wrong results in religion: 1
# No results found for Arizona in beach
# --------------------------------------------------------------------------------
# Searching CALIFORNIA
# Number of wrong results in religion: 1
# Number of wrong results in beach: 1
# --------------------------------------------------------------------------------
# Searching COLORADO
# Number of wrong results in beach: 1
# --------------------------------------------------------------------------------
# Searching CONNECTICUT
# Number of wrong results in beach: 1
# --------------------------------------------------------------------------------
# Searching DELAWARE
# Maryland is not in the state of Delaware!
# Number of wrong results in tourism: 1
# Number of wrong results in beach: 1
# Maryland is not in the state of Delaware!
# Number of wrong results in production: 1
# --------------------------------------------------------------------------------
# Searching FLORIDA
# Number of wrong results in beach: 1
# --------------------------------------------------------------------------------
# Searching GEORGIA
# Number of wrong results in tourism: 1
# No results found for Georgia in beach
# --------------------------------------------------------------------------------
# Searching HAWAII
# Number of wrong results in beach: 1
# --------------------------------------------------------------------------------
# Searching IOWA
# Number of wrong results in tourism: 1
# Number of wrong results in beach: 1
# --------------------------------------------------------------------------------
# Searching IDAHO
# Number of wrong results in beach: 1
# No results found for Idaho in production
# --------------------------------------------------------------------------------
# Searching ILLINOIS
# Number of wrong results in beach: 1
# --------------------------------------------------------------------------------
# Searching INDIANA
# Number of wrong results in beach: 1
# --------------------------------------------------------------------------------
# Searching KANSAS
# Number of wrong results in religion: 1
# Number of wrong results in beach: 1
# --------------------------------------------------------------------------------
# Searching KENTUCKY
# Number of wrong results in beach: 1
# --------------------------------------------------------------------------------
# Searching LOUISIANA
# Number of wrong results in tourism: 1
# No results found for Louisiana in beach
# --------------------------------------------------------------------------------
# Searching MASSACHUSETTS
# Number of wrong results in beach: 1
# --------------------------------------------------------------------------------
# Searching MARYLAND
# Number of wrong results in tourism: 1
# Number of wrong results in beach: 1
# --------------------------------------------------------------------------------
# Searching MAINE
# Number of wrong results in beach: 1
# --------------------------------------------------------------------------------
# Searching MICHIGAN
# Number of wrong results in religion: 1
# Number of wrong results in beach: 1
# No results found for Michigan in production
# --------------------------------------------------------------------------------
# Searching MINNESOTA
# Number of wrong results in tourism: 1
# Number of wrong results in beach: 1
# --------------------------------------------------------------------------------
# Searching MISSOURI
# Number of wrong results in tourism: 1
# No results found for Missouri in beach
# --------------------------------------------------------------------------------
# Searching MISSISSIPPI
# No results found for Mississippi in beach
# --------------------------------------------------------------------------------
# Searching MONTANA
# Number of wrong results in religion: 1
# No results found for Montana in beach
# --------------------------------------------------------------------------------
# Searching NORTH CAROLINA
# Number of wrong results in beach: 1
# --------------------------------------------------------------------------------
# Searching NORTH DAKOTA
# No results found for North Dakota in tourism
# --------------------------------------------------------------------------------
# Searching NEBRASKA
# No results found for Nebraska in beach
# --------------------------------------------------------------------------------
# Searching NEW HAMPSHIRE
# Number of wrong results in beach: 1
# --------------------------------------------------------------------------------
# Searching NEW JERSEY
# Number of wrong results in beach: 1
# Pennsylvania is not in the state of New Jersey!
# Number of wrong results in production: 1
# --------------------------------------------------------------------------------
# Searching NEW MEXICO
# Number of wrong results in tourism: 1
# No results found for New Mexico in beach
# --------------------------------------------------------------------------------
# Searching NEVADA
# No results found for Nevada in commercial
# --------------------------------------------------------------------------------
# Searching NEW YORK
# Number of wrong results in beach: 1
# --------------------------------------------------------------------------------
# Searching OHIO
# Number of wrong results in tourism: 1
# Number of wrong results in beach: 1
# --------------------------------------------------------------------------------
# Searching OKLAHOMA
# No results found for Oklahoma in beach
# --------------------------------------------------------------------------------
# Searching OREGON
# No results found for Oregon in commercial
# --------------------------------------------------------------------------------
# Searching PENNSYLVANIA
# Number of wrong results in beach: 1
# --------------------------------------------------------------------------------
# Searching RHODE ISLAND
# Number of wrong results in religion: 1
# Number of wrong results in beach: 1
# --------------------------------------------------------------------------------
# Searching SOUTH CAROLINA
# Number of wrong results in tourism: 1
# Number of wrong results in beach: 1
# --------------------------------------------------------------------------------
# Searching SOUTH DAKOTA
# No results found for South Dakota in tourism
# --------------------------------------------------------------------------------
# Searching TENNESSEE
# Number of wrong results in beach: 1
# --------------------------------------------------------------------------------
# Searching TEXAS
# Number of wrong results in tourism: 1
# No results found for Texas in beach
# --------------------------------------------------------------------------------
# Searching UTAH
# Number of wrong results in beach: 1
# No results found for Utah in production
# --------------------------------------------------------------------------------
# Searching VIRGINIA
# Number of wrong results in beach: 1
# --------------------------------------------------------------------------------
# Searching VERMONT
# Number of wrong results in beach: 1
# --------------------------------------------------------------------------------
# Searching WASHINGTON
# Number of wrong results in beach: 1
# --------------------------------------------------------------------------------
# Searching WISCONSIN
# Number of wrong results in tourism: 1
# Number of wrong results in religion: 1
# Number of wrong results in beach: 1
# --------------------------------------------------------------------------------
# Searching WEST VIRGINIA
# Number of wrong results in tourism: 1
# Number of wrong results in beach: 1
# --------------------------------------------------------------------------------
# Searching WYOMING
# No results found for Wyoming in religion
# --------------------------------------------------------------------------------
# Ending Services Search
# Number of Places API response with no data: 20

# %% [markdown]
# # Test Request Below

# %%
# TEST CATEGORY REQUEST HERE

# test_places_url = 'https://api.geoapify.com/v2/places?'

# # Select the categories that you want to search and test it in California
# test_params = {
#             "categories": "beach",
#             "apiKey": api_key,
#             "limit": 3,
#             "filter": f"rect:{states_df['lon1'][4]},{states_df['lat1'][4]},{states_df['lon2'][4]},{states_df['lat2'][4]}",
#         }
# test_json = requests.get(test_places_url, params=test_params).json()

# test_data = []
# for feature in test_json['features']:
#     test_placeID = feature['properties']['place_id']
#     test_geocode_url = 'https://api.geoapify.com/v1/geocode/search?'
#     try:
#         test_params_geocode = {
#                 "apiKey": api_key,
#                 "text": feature['properties']['formatted'],
#                 "limit": 1,
#                 "filter": f"place:{test_placeID}",
#             }
#     except KeyError:
#         test_params_geocode = {
#                 "apiKey": api_key,
#                 "text": feature['properties']['categories'],
#                 "limit": 1,
#                 "filter": f"place:{test_placeID}",
#             }
#     test_geocode_json = requests.get(test_geocode_url, params=test_params_geocode).json()
#     for geo_feature in test_geocode_json['features']:
#         if ((geo_feature['properties']['rank']['confidence'] == 1) | (geo_feature['properties']['rank']['match_type'] == "full_match") | (geo_feature['properties']['rank']['match_type'] == "match_by_building")):
#             try:
#                 test_data.append(geo_feature['properties']['rank']['popularity'])
#                 print(geo_feature['properties']['rank']['popularity'])
#             except KeyError:
#                 test_data.append(None)
        
#     print(json.dumps(test_geocode_json, indent= 4, sort_keys=True))
# Out:
# {
#     "features": [
#         {
#             "bbox": [
#                 -118.9015576,
#                 36.787263,
#                 -118.9006472,
#                 36.7885309
#             ],
#             "geometry": {
#                 "coordinates": [
#                     -118.90095516756642,
#                     36.7878554
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Sandy Cove Beach",
#                 "address_line2": "Fresno County, CA, United States of America",
#                 "category": "beach",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Fresno County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "formatted": "Sandy Cove Beach, Fresno County, CA, United States of America",
#                 "lat": 36.7878554,
#                 "lon": -118.90095516756642,
#                 "name": "Sandy Cove Beach",
#                 "place_id": "510af7dc3fa9b95dc0590e7d1c72d8644240f00102f901778fba1200000000c0020192031053616e647920436f7665204265616368",
#                 "plus_code": "8583Q3QX+4J",
#                 "rank": {
#                     "confidence": 0.7290000000000001,
#                     "confidence_city_level": 0.9,
#                     "confidence_street_level": 0.7290000000000001,
#                     "importance": 0.2000099999999999,
#                     "match_type": "inner_part"
#                 },
#                 "result_type": "amenity",
#                 "state": "California",
#                 "state_code": "CA",
#                 "timezone": {
#                     "abbreviation_DST": "PDT",
#                     "abbreviation_STD": "PST",
#                     "name": "America/Los_Angeles",
#                     "offset_DST": "-07:00",
#                     "offset_DST_seconds": -25200,
#                     "offset_STD": "-08:00",
#                     "offset_STD_seconds": -28800
#                 }
#             },
#             "type": "Feature"
#         }
#     ],
#     "query": {
#         "parsed": {
#             "city": "cove beach",
#             "country": "united states of america",
#             "county": "fresno county",
#             "expected_type": "street",
#             "state": "california",
#             "street": "sandy"
#         },
#         "text": "Sandy Cove Beach, Fresno County, California, United States of America"
#     },
#     "type": "FeatureCollection"
# }
# 1.1837504212494745
# {
#     "features": [
#         {
#             "bbox": [
#                 -119.1357557,
#                 38.0148737,
#                 -119.1356557,
#                 38.0149737
#             ],
#             "geometry": {
#                 "coordinates": [
#                     -119.1357057,
#                     38.0149237
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Danburg Beach",
#                 "address_line2": "Mono County, CA, United States of America",
#                 "category": "beach",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Mono County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "formatted": "Danburg Beach, Mono County, CA, United States of America",
#                 "lat": 38.0149237,
#                 "lon": -119.1357057,
#                 "name": "Danburg Beach",
#                 "place_id": "515fd8f566afc85dc059b8b71105e9014340f00103f901acd0621500000000c0020192030d44616e62757267204265616368",
#                 "plus_code": "85C22V77+XP",
#                 "rank": {
#                     "confidence": 1,
#                     "confidence_city_level": 1,
#                     "importance": 0.4000099999999999,
#                     "match_type": "inner_part",
#                     "popularity": 1.1837504212494745
#                 },
#                 "result_type": "amenity",
#                 "state": "California",
#                 "state_code": "CA",
#                 "timezone": {
#                     "abbreviation_DST": "PDT",
#                     "abbreviation_STD": "PST",
#                     "name": "America/Los_Angeles",
#                     "offset_DST": "-07:00",
#                     "offset_DST_seconds": -25200,
#                     "offset_STD": "-08:00",
#                     "offset_STD_seconds": -28800
#                 }
#             },
#             "type": "Feature"
#         }
#     ],
#     "query": {
#         "parsed": {
#             "city": "danburg beach",
#             "country": "united states of america",
#             "county": "mono county",
#             "expected_type": "city",
#             "state": "california"
#         },
#         "text": "Danburg Beach, Mono County, California, United States of America"
#     },
#     "type": "FeatureCollection"
# }
# 1.1973385967826011
# {
#     "features": [
#         {
#             "bbox": [
#                 -119.0196397,
#                 37.941543,
#                 -119.0195397,
#                 37.941643
#             ],
#             "geometry": {
#                 "coordinates": [
#                     -119.0195897,
#                     37.941593
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Navy Beach",
#                 "address_line2": "Mono County, CA, United States of America",
#                 "category": "beach",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Mono County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database License",
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "formatted": "Navy Beach, Mono County, CA, United States of America",
#                 "lat": 37.941593,
#                 "lon": -119.0195897,
#                 "name": "Navy Beach",
#                 "place_id": "51a93528f540c15dc0593e92921e86f84240f00103f9016d62631500000000c0020192030a4e617679204265616368",
#                 "plus_code": "8592WXRJ+J5",
#                 "rank": {
#                     "confidence": 1,
#                     "confidence_city_level": 1,
#                     "importance": 0.4000099999999999,
#                     "match_type": "inner_part",
#                     "popularity": 1.1973385967826011
#                 },
#                 "result_type": "amenity",
#                 "state": "California",
#                 "state_code": "CA",
#                 "timezone": {
#                     "abbreviation_DST": "PDT",
#                     "abbreviation_STD": "PST",
#                     "name": "America/Los_Angeles",
#                     "offset_DST": "-07:00",
#                     "offset_DST_seconds": -25200,
#                     "offset_STD": "-08:00",
#                     "offset_STD_seconds": -28800
#                 }
#             },
#             "type": "Feature"
#         }
#     ],
#     "query": {
#         "parsed": {
#             "city": "navy beach",
#             "country": "united states of america",
#             "county": "mono county",
#             "expected_type": "city",
#             "state": "california"
#         },
#         "text": "Navy Beach, Mono County, California, United States of America"
#     },
#     "type": "FeatureCollection"
# }

# %%
# RUNNING THIS CELL WILL COPY THE states_df AND PERFORM A RANDOM NUMBER SAMPLING

states_popularity_df = states_df.copy()

# Pick the columns with the popularity for each category searched
states_popularity_df = states_popularity_df[['state', 'name', 'commercial_popularity', 'service_popularity', 'religion_popularity', 'tourism_popularity', 'production_popularity', 'leisure_popularity']]

for index, row in states_popularity_df.iterrows():
    count_nan = 0
    for pop in states_popularity_df.columns[2:]:
        if np.isnan(states_popularity_df.loc[index, pop]):
            states_popularity_df.at[index, pop] = random.uniform(0, states_popularity_df.loc[:, pop].max() / 5)
            count_nan += 1   
    print(f"Number of NaN values for {states_popularity_df.loc[index, 'name']}: {count_nan}")

states_popularity_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Hansle Goh\Desktop\Bootcamp Projects\project-1\Services\services.ipynb Cell 7 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/Hansle%20Goh/Desktop/Bootcamp%20Projects/project-1/Services/services.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> # RUNNING THIS CELL WILL COPY THE states_df AND PERFORM A RANDOM NUMBER SAMPLING
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Hansle%20Goh/Desktop/Bootcamp%20Projects/project-1/Services/services.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> states_popularity_df = states_df.copy()
#       <a href='vscode-notebook-cell:/c%3A/Users/Hansle%20Goh/Desktop/Bootcamp%20Projects/project-1/Services/services.ipynb#X12sZmlsZQ%3D%3D?line=4'>5</a> # Pick the columns with the popularity for each category searched
#       <a href='vscode-notebook-cell:/c%3A/Users/Hansle%20Goh/Desktop/Bootcamp%20Projects/project-1/Services/services.ipynb#X12sZmlsZQ%3D%3D?line=5'>6</a> states_popularity_df = states_popularity_df[['state', 'name', 'commercial_popularity', 'service_popularity', 'religion_popularity', 'tourism_popularity', 'production_popularity', 'leisure_popularity']]
#
# NameError: name 'states_df' is not defined

# %%
# Export the popularity Dataframe as a csv file
states_popularity_df.to_csv('states_popularity.csv', index=False)
